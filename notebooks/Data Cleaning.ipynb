# %%
from ada_project_helpers import *

# %%
area_mapping, element_mapping, item_mapping = create_mappings(verbose=True)
# Out:
#  ----------  WARNING   ---------
# Conflict in building mapping -- first values will be kept:
#                                                 Area
# Area Code
# 167                                          Czechia
# 209                                         Eswatini
# 154                                  North Macedonia
# 299                                        Palestine
# 5501                       Australia and New Zealand
# 167                                   Czech Republic
# 209                                        Swaziland
# 154        The former Yugoslav Republic of Macedonia
# 299                   Occupied Palestinian Territory
# 5501                         Australia & New Zealand
#  ---------------------------------
#
#
#  ----------  WARNING   ---------
# Conflict in building mapping -- first values will be kept:
#                                                 Area
# Area Code
# 167                                          Czechia
# ...
